# %%
# How to read CSV Dataset using Pandas & Analysis Work

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
movies=pd.read_csv("dataset/movies.csv")# automatically converts data into df

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
movies# shows starting 5 and last 5 data
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 975          7.4                                          Tootsie
# 976          7.4                      Back to the Future Part III
# 977          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Poltergeist
# 979          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies.shape
# Out:
# (980, 6)

# %% [markdown]
# 980 samples and 6 features

# %%
movies.head()# bydefault shows starting 5 record
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.head(10)
# Out:
#    star_rating                                          title content_rating  \
# 0          9.3                       The Shawshank Redemption              R
# 1          9.2                                  The Godfather              R
# 2          9.1                         The Godfather: Part II              R
# 3          9.0                                The Dark Knight          PG-13
# 4          8.9                                   Pulp Fiction              R
# 5          8.9                                   12 Angry Men      NOT RATED
# 6          8.9                 The Good, the Bad and the Ugly      NOT RATED
# 7          8.9  The Lord of the Rings: The Return of the King          PG-13
# 8          8.9                               Schindler's List              R
# 9          8.9                                     Fight Club              R
#
#        genre  duration                                        actors_list
# ...

# %%
movies.tail()# last 5 records
# Out:
#      star_rating                                            title  \
# 975          7.4                                          Tootsie
# 976          7.4                      Back to the Future Part III
# 977          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Poltergeist
# 979          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 975             PG     Comedy       116
# 976             PG  Adventure       118
# 977          PG-13     Action       138
# 978             PG     Horror       114
# 979              R      Crime       126
#
#                                            actors_list
# 975  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 976  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 977  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 978  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# ...

# %%
movies.tail(3)
# Out:
#      star_rating                                            title  \
# 977          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Poltergeist
# 979          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 977          PG-13  Action       138
# 978             PG  Horror       114
# 979              R   Crime       126
#
#                                            actors_list
# 977  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 978  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 979  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...

# %%
movies.sample()# random one record eveytime displays diff record
# Out:
#      star_rating               title content_rating  genre  duration  \
# 217          8.1  Memories of Murder        UNRATED  Crime       132
#
#                                            actors_list
# 217  [u'Kang-ho Song', u'Sang-kyung Kim', u'Roe-ha ...

# %%
movies.sample(5)# 5 random records
# Out:
#      star_rating             title content_rating      genre  duration  \
# 310          8.0          Big Fish          PG-13  Adventure       125
# 903          7.5            Frenzy              R   Thriller       116
# 539          7.8  The White Ribbon              R      Drama       144
# 572          7.8      A Bronx Tale              R      Crime       121
# 345          8.0     No Man's Land              R      Drama        98
#
#                                            actors_list
# 310  [u'Ewan McGregor', u'Albert Finney', u'Billy C...
# 903   [u'Jon Finch', u'Barry Foster', u'Alec McCowen']
# 539  [u'Christian Friedel', u'Ernst Jacobi', u'Leon...
# 572  [u'Robert De Niro', u'Chazz Palminteri', u'Lil...
# 345  [u'Branko Djuric', u'Rene Bitorajac', u'Filip ...

# %%
movies.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
# to show each and every record
pd.set_option('display.max_rows',None)

# %%
movies
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
movies.describe()# bydefault takes on numeric data
# Out:
#        star_rating    duration
# count   980.000000  980.000000
# mean      7.889796  120.942857
# std       0.335898   26.229809
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
movies.describe(include=['object'])# to see on str data
# Out:
#           title content_rating  genre  \
# count       980            977    980
# unique      976             12     16
# top     Dracula              R  Drama
# freq          2            461    279
#
#                                               actors_list
# count                                                 980
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
# to identify missing details or other info
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     980 non-null    float64
#  1   title           980 non-null    object
#  2   content_rating  977 non-null    object
#  3   genre           980 non-null    object
#  4   duration        980 non-null    int64
#  5   actors_list     980 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.1+ KB

# %% [markdown]
# 977 having missing record not having 980

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.genre.value_counts()# to see types of movies with theiir counts
# Out:
# genre
# Drama        279
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: count, dtype: int64

# %%
movies.genre.value_counts().head(3)
# Out:
# genre
# Drama     279
# Comedy    156
# Action    136
# Name: count, dtype: int64

# %%
movies.genre.value_counts()[:3]
# Out:
# genre
# Drama     279
# Comedy    156
# Action    136
# Name: count, dtype: int64

# %%
movies.genre.value_counts().tail(3)
# Out:
# genre
# Family     2
# History    1
# Fantasy    1
# Name: count, dtype: int64

# %%
movies.genre.value_counts()[:-4:-1]
# Out:
# genre
# Fantasy    1
# History    1
# Family     2
# Name: count, dtype: int64

# %%
movies.genre.value_counts()[:3].plot(kind='bar',cmap='spring')
plt.show()

# %%
movies.genre.value_counts().tail(3).plot(kind='bar',cmap='spring')
plt.show()

# %%
 # >=200 minutes list
movies['duration']>=200
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
# 5      False
# 6      False
# 7       True
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17      True
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# ...

# %%
movies[movies['duration']>=200]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 446          7.9                           The Ten Commandments
# 477          7.8                                         Hamlet
# 631          7.7                                      Malcolm X
# 768          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
movies[movies['duration']>=200].shape# 12 movies
# Out:
# (12, 6)

# %%
movies[movies['duration']>=200].genre.value_counts()
# Out:
# genre
# Adventure    5
# Drama        3
# Crime        2
# Biography    1
# Action       1
# Name: count, dtype: int64

# %%
movies[movies['duration']>=200].genre.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='genre'>

# %% [markdown]
# ### Top 3 Highest Duration movies list,Title,Duration

# %% [markdown]
# m=movies.sort_values(by='duration',ascending=False)[:3]
# m

# %%
m.iloc[:,[1,4]]
# Out:
#                            title  duration
# 477                       Hamlet       242
# 157           Gone with the Wind       238
# 78   Once Upon a Time in America       229

# %%
movies.loc[movies.sort_values(by='duration',ascending=False).index.tolist(),['title','duration']].head(3)
# Out:
#                            title  duration
# 477                       Hamlet       242
# 157           Gone with the Wind       238
# 78   Once Upon a Time in America       229

# %% [markdown]
# ### Only those movies starting from Once

# %%
movies[movies.title.str.startswith('Once')]
# Out:
#      star_rating                         title content_rating    genre  \
# 26           8.6  Once Upon a Time in the West          PG-13  Western
# 78           8.4   Once Upon a Time in America              R    Crime
# 403          7.9                          Once              R    Drama
#
#      duration                                        actors_list
# 26        175  [u'Henry Fonda', u'Charles Bronson', u'Claudia...
# 78        229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 403        85  [u'Glen Hansard', u'Mark\xe9ta Irglov\xe1', u'...

# %% [markdown]
# # problem is once could be"ONCE",'Once'

# %%
import re
def check(x):
    m=re.search('^once',x,re.I)
    if m:
        return True
    else:
        return False

# %%
movies[movies.title.apply(check)]# now this will include all once# apply is used in place of loop to call func by checking each index of title and is very fast as comp to loop
# Out:
#      star_rating                         title content_rating    genre  \
# 26           8.6  Once Upon a Time in the West          PG-13  Western
# 78           8.4   Once Upon a Time in America              R    Crime
# 401          7.9                          once              R    Drama
# 403          7.9                          Once              R    Drama
#
#      duration                                        actors_list
# 26        175  [u'Henry Fonda', u'Charles Bronson', u'Claudia...
# 78        229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 401        85  [u'Glen Hansard', u'Mark\xe9ta Irglov\xe1', u'...
# 403        85  [u'Glen Hansard', u'Mark\xe9ta Irglov\xe1', u'...

# %%
movies.title.head()
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2      The Godfather: Part II
# 3             The Dark Knight
# 4                Pulp Fiction
# Name: title, dtype: object

# %%
movies.title.apply(str.upper).head()# apply is high order func
# Out:
# 0    THE SHAWSHANK REDEMPTION
# 1               THE GODFATHER
# 2      THE GODFATHER: PART II
# 3             THE DARK KNIGHT
# 4                PULP FICTION
# Name: title, dtype: object

# %%
movies.title.apply(str.lower).head()
# Out:
# 0    the shawshank redemption
# 1               the godfather
# 2      the godfather: part ii
# 3             the dark knight
# 4                pulp fiction
# Name: title, dtype: object

# %%
movies.title.apply(str.swapcase).head()
# Out:
# 0    tHE sHAWSHANK rEDEMPTION
# 1               tHE gODFATHER
# 2      tHE gODFATHER: pART ii
# 3             tHE dARK kNIGHT
# 4                pULP fICTION
# Name: title, dtype: object

# %% [markdown]
# ### How to find out missing record

# %%
movies.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %% [markdown]
# colmn content_rating have 3 missing records

# %%
movies[movies.content_rating.isnull()]# to check those  movies with missing content_rating
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 650          7.7                   Where Eagles Dare            NaN
# 937          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 650     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 937  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %% [markdown]
# ### >60 & <=70 minutes movies

# %%
movies[(movies['duration']>=60)&(movies['duration']<=70)]
# Out:
#      star_rating                        title content_rating    genre  \
# 88           8.4                      The Kid      NOT RATED   Comedy
# 258          8.1  The Cabinet of Dr. Caligari        UNRATED    Crime
# 293          8.1                    Duck Soup         PASSED   Comedy
# 338          8.0          Battleship Potemkin        UNRATED  History
# 351          8.0                 Frankenstein        UNRATED   Horror
# 389          8.0                       Freaks        UNRATED    Drama
# 743          7.6                    Following              R  Mystery
#
#      duration                                        actors_list
# 88         68  [u'Charles Chaplin', u'Edna Purviance', u'Jack...
# 258        67  [u'Werner Krauss', u'Conrad Veidt', u'Friedric...
# 293        68    [u'Groucho Marx', u'Harpo Marx', u'Chico Marx']
# 338        66  [u'Aleksandr Antonov', u'Vladimir Barsky', u'G...
# 351        70  [u'Colin Clive', u'Mae Clarke', u'Boris Karloff']
# ...

# %%
movies[(movies['duration']>=60)&(movies['duration']<=70)].shape# to know total movies
# Out:
# (7, 6)

# %%
movies[(movies['duration']>=60)&(movies['duration']<=70)].genre.value_counts()
# Out:
# genre
# Comedy     2
# Crime      1
# History    1
# Horror     1
# Drama      1
# Mystery    1
# Name: count, dtype: int64

# %%
movies[movies.duration.isin(range(60,71))]#isin method checks condn for the given range
# Out:
#      star_rating                        title content_rating    genre  \
# 88           8.4                      The Kid      NOT RATED   Comedy
# 258          8.1  The Cabinet of Dr. Caligari        UNRATED    Crime
# 293          8.1                    Duck Soup         PASSED   Comedy
# 338          8.0          Battleship Potemkin        UNRATED  History
# 351          8.0                 Frankenstein        UNRATED   Horror
# 389          8.0                       Freaks        UNRATED    Drama
# 743          7.6                    Following              R  Mystery
#
#      duration                                        actors_list
# 88         68  [u'Charles Chaplin', u'Edna Purviance', u'Jack...
# 258        67  [u'Werner Krauss', u'Conrad Veidt', u'Friedric...
# 293        68    [u'Groucho Marx', u'Harpo Marx', u'Chico Marx']
# 338        66  [u'Aleksandr Antonov', u'Vladimir Barsky', u'G...
# 351        70  [u'Colin Clive', u'Mae Clarke', u'Boris Karloff']
# ...

# %%
movies[movies.duration.isin(range(60,71))].shape
# Out:
# (7, 6)

# %%
# movie list with only drama ,crime , action
movies[movies.genre.isin(['Drama','Crime','Action'])]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# 5            8.9                                     12 Angry Men
# 9            8.9                                       Fight Club
# 11           8.8                                        Inception
# 12           8.8   Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                     Forrest Gump
# 16           8.7                  One Flew Over the Cuckoo's Nest
# 17           8.7                                    Seven Samurai
# 19           8.7                                        Star Wars
# ...

# %%
movies[movies.genre.isin(['Drama','Crime','Action'])].shape
# Out:
# (539, 6)

# %%
movies[movies.genre.isin(['Drama','Crime','Action'])].genre.value_counts()
# Out:
# genre
# Drama     279
# Action    136
# Crime     124
# Name: count, dtype: int64

# %%
movies[movies.genre.isin(['Drama','Crime','Action'])].genre.value_counts().plot(kind='pie')
plt.show()

# %%
movies.actors_list.head()
# Out:
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# Name: actors_list, dtype: object

# %%
movies[movies.actors_list.str.contains('Aamir Khan',case=False)]
# Out:
#      star_rating                              title content_rating      genre  \
# 47           8.5                   Taare Zameen Par             PG      Drama
# 60           8.5                           3 Idiots          PG-13     Comedy
# 72           8.4                    Rang De Basanti      NOT RATED      Drama
# 109          8.3                     Dil Chahta Hai      NOT RATED     Comedy
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
#
#      duration                                        actors_list
# 47        165  [u'Darsheel Safary', u'Aamir Khan', u'Tanay Ch...
# 60        170        [u'Aamir Khan', u'Madhavan', u'Mona Singh']
# 72        157    [u'Aamir Khan', u'Soha Ali Khan', u'Siddharth']
# 109       183  [u'Aamir Khan', u'Saif Ali Khan', u'Akshaye Kh...
# 142       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...

# %%
movies[movies.actors_list.str.contains('priyanka',case=False)]
# Out:
#      star_rating   title content_rating      genre  duration  \
# 133          8.3  Barfi!      NOT RATED  Adventure       151
#
#                                            actors_list
# 133  [u'Ranbir Kapoor', u'Priyanka Chopra', u'Ileana']

# %%
#movies with star rating greater than 8
movies[movies.star_rating>8]
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
movies[movies.star_rating>8].shape
# Out:
# (297, 6)

# %%
movies[movies.star_rating>8].genre.value_counts()
# Out:
# genre
# Drama        92
# Crime        43
# Comedy       38
# Action       37
# Adventure    25
# Biography    20
# Animation    18
# Mystery       9
# Western       7
# Horror        5
# Film-Noir     2
# Sci-Fi        1
# Name: count, dtype: int64

# %%
movies[movies.star_rating>8].genre.value_counts().plot(kind='bar')
plt.show()

# %%
movies.genre.unique()#types of movies
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
movies.genre.nunique() #(nunique=no. of unique) 16 types of movies
# Out:
# 16

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
# to fetch movies with num datatype
movies.select_dtypes(include=['float64','int64'])
# Out:
#      star_rating  duration
# 0            9.3       142
# 1            9.2       175
# 2            9.1       200
# 3            9.0       152
# 4            8.9       154
# 5            8.9        96
# 6            8.9       161
# 7            8.9       201
# 8            8.9       195
# 9            8.9       139
# 10           8.8       178
# 11           8.8       148
# 12           8.8       124
# 13           8.8       142
# 14           8.8       179
# 15           8.7       169
# 16           8.7       133
# 17           8.7       207
# 18           8.7       146
# 19           8.7       121
# 20           8.7       136
# 21           8.7       130
# 22           8.7       130
# 23           8.7       106
# 24           8.7       127
# 25           8.6       116
# 26           8.6       175
# 27           8.6       118
# 28           8.6       110
# 29           8.6        87
# 30           8.6       125
# 31           8.6       112
# 32           8.6       102
# ...

# %% [markdown]
# or

# %%
movies.select_dtypes(exclude=['object'])
# Out:
#      star_rating  duration
# 0            9.3       142
# 1            9.2       175
# 2            9.1       200
# 3            9.0       152
# 4            8.9       154
# 5            8.9        96
# 6            8.9       161
# 7            8.9       201
# 8            8.9       195
# 9            8.9       139
# 10           8.8       178
# 11           8.8       148
# 12           8.8       124
# 13           8.8       142
# 14           8.8       179
# 15           8.7       169
# 16           8.7       133
# 17           8.7       207
# 18           8.7       146
# 19           8.7       121
# 20           8.7       136
# 21           8.7       130
# 22           8.7       130
# 23           8.7       106
# 24           8.7       127
# 25           8.6       116
# 26           8.6       175
# 27           8.6       118
# 28           8.6       110
# 29           8.6        87
# 30           8.6       125
# 31           8.6       112
# 32           8.6       102
# ...

# %%
#to show first 5 records
movies.select_dtypes(exclude=['object'])[:5]
# Out:
#    star_rating  duration
# 0          9.3       142
# 1          9.2       175
# 2          9.1       200
# 3          9.0       152
# 4          8.9       154

# %%
movies.select_dtypes(include=['object'])
# Out:
#                                                  title content_rating  \
# 0                             The Shawshank Redemption              R
# 1                                        The Godfather              R
# 2                               The Godfather: Part II              R
# 3                                      The Dark Knight          PG-13
# 4                                         Pulp Fiction              R
# 5                                         12 Angry Men      NOT RATED
# 6                       The Good, the Bad and the Ugly      NOT RATED
# 7        The Lord of the Rings: The Return of the King          PG-13
# 8                                     Schindler's List              R
# 9                                           Fight Club              R
# 10   The Lord of the Rings: The Fellowship of the Ring          PG-13
# 11                                           Inception          PG-13
# ...
